# %%
import tensorflow as tf
import keras as keras

# %%
print("tensorflow:", tf.__version__)
print("keras:", keras.__version__)
# Out:
# tensorflow: 2.10.0
# keras: 2.10.0

# %%
import sys
import numpy as np
import matplotlib

# %%
print("Python:", sys.version)
print("Numpy:", np.__version__)
print("Matplotlib: ", matplotlib.__version__)
# Out:
# Python: 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:15:57) [MSC v.1916 64 bit (AMD64)]
# Numpy: 1.26.4
# Matplotlib:  3.8.4

# %%
# simple NN (Perceptron) with 3 inputs 
inputs = [1, 2, 3, 2.5]
weights = [.2, .8, -.5, 1.0]
bias = 2

output = inputs[0]*weights[0]+inputs[1]*weights[1]+inputs[2]*weights[2] + inputs[3]*weights[3] + bias

print(output)
# Out:
# 4.8

# %%
import matplotlib.pyplot as plt

# Initialize the input values, weights, and bias
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2.0

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the perceptron components
# Inputs
input_positions = [(0, 3), (0, 2), (0, 1)]
for i, pos in enumerate(input_positions):
    ax.text(pos[0] - 0.1, pos[1], f'Input {inputs[i]}', fontsize=12, ha='right')
    ax.scatter(pos[0], pos[1], s=1000, color='skyblue', edgecolor='black')

# Weights
weight_positions = [(1, 2.5), (1, 2), (1, 1.5)]
for i, pos in enumerate(weight_positions):
    ax.text(pos[0] + 0.1, pos[1], f'Weight {weights[i]}', fontsize=12, va='center')
    ax.plot([0, 1], [input_positions[i][1], pos[1]], color='gray')

# Bias
ax.scatter(1.5, 2, s=1000, color='lightgreen', edgecolor='black')
ax.text(1.5, 2.2, f'Bias {bias}', fontsize=12, ha='center')

# Output
ax.scatter(3, 2, s=1000, color='salmon', edgecolor='black')
ax.text(3.1, 2, 'Output', fontsize=12, ha='left')

# Draw lines to the output
for i, pos in enumerate(weight_positions):
    ax.plot([1, 3], [pos[1], 2], color='gray')

# Set the axis limits and hide the axis
ax.set_xlim(-0.5, 4)
ax.set_ylim(0.5, 3.5)
ax.axis('off')

# Display the perceptron diagram
plt.title('Perceptron with 3 Inputs, Weights, and Bias')
plt.show()

# %%
# 4 inputs, 3 neurons
inputs = [1, 2, 3, 2.5]

weights1 = [.2, .8, -.5, 1.0]
weights2 = [.5, -.91, .26, -.5]
weights3 = [-.26, -.27, .17, .87]

bias1 = 2
bias2 = 3
bias3 = .5

# use list to obtain output
output = [inputs[0]*weights1[0]+inputs[1]*weights1[1]+inputs[2]*weights1[2] + inputs[3]*weights1[3] + bias1,
          inputs[0]*weights2[0]+inputs[1]*weights2[1]+inputs[2]*weights2[2] + inputs[3]*weights2[3] + bias2,
          inputs[0]*weights3[0]+inputs[1]*weights3[1]+inputs[2]*weights3[2] + inputs[3]*weights3[3] + bias3]
print(output)
# Out:
# [4.8, 1.21, 2.385]

# %%
import matplotlib.pyplot as plt

# Define the inputs, weights, and biases
inputs = [1, 2, 3, 2.5]
weights = [[0.2, 0.8, -0.5, 1.0], [0.5, -0.91, 0.26, -0.5], [-0.26, -0.27, 0.17, 0.87]]
biases = [2, 3, 0.5]

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Draw the neural network components
# Inputs
input_positions = [(0, 4), (0, 3), (0, 2), (0, 1)]
for i, pos in enumerate(input_positions):
    ax.text(pos[0] - 0.1, pos[1], f'Input {inputs[i]}', fontsize=12, ha='right')
    ax.scatter(pos[0], pos[1], s=1000, color='skyblue', edgecolor='black')

# Weights and Outputs
output_positions = [(3, 3.5), (3, 2.5), (3, 1.5)]
output_names = ['Output 1', 'Output 2', 'Output 3']

for i, output_pos in enumerate(output_positions):
    # Draw the output neuron
    ax.scatter(output_pos[0], output_pos[1], s=1000, color='salmon', edgecolor='black')
    ax.text(output_pos[0] + 0.2, output_pos[1], output_names[i], fontsize=12, ha='left')

    # Connect each input to the output neuron
    for j, input_pos in enumerate(input_positions):
        ax.plot([input_pos[0], output_pos[0]], [input_pos[1], output_pos[1]], color='gray')

    # Display the bias
    ax.text(output_pos[0] - 0.2, output_pos[1] + 0.3, f'Bias: {biases[i]}', fontsize=12, ha='center')

# Set the axis limits and hide the axis
ax.set_xlim(-0.5, 4)
ax.set_ylim(0.5, 4.5)
ax.axis('off')

# Display the neural network structure
plt.title('Neural Network Structure with Inputs, Weights, and Biases')
plt.show()

# Calculate and print the output of the network
output = [
    sum(inputs[j] * weights[0][j] for j in range(len(inputs))) + biases[0],
    sum(inputs[j] * weights[1][j] for j in range(len(inputs))) + biases[1],
    sum(inputs[j] * weights[2][j] for j in range(len(inputs))) + biases[2],
]
print(f'Output: {output}')
# Out:
# Output: [4.8, 1.21, 2.385]

# %%
# Use list
# 4 inputs, 3 neurons
inputs = [1, 2, 3, 2.5]

# Shape (dim) is (3, 4): 2D array, Matrix
weights = [[.2, .8, -.5, 1.0],
           [.5, -.91, .26, -.5],
           [-.26, -.27, .17, .87]]

biases = [2, 3, .5]


# employ dot product next
# Out:
# [4.8, 1.21, 2.385]

# %%
# employ dot product
import numpy as np

inputs = [1, 2, 3, 2.5]

weights = [.2, .8, -.5, 1.0]

bias = 2

output = np.dot(weights, inputs) + bias
print(output)
# Out:
# 4.8

# %%
weights = [[.2, .8, -.5, 1.0],
           [.5, -.91, .26, -.5],
           [-.26, -.27, .17, .87]]

biases = [2, 3, .5]
output = np.dot(weights, inputs) + biases # w'*x + b 
print(output)
# Out:
# [4.8   1.21  2.385]

# %%
# Batches of inputs
# list of shape (3,4) input matrix
inputs = [[1.0, 2.0, 3.0, 2.5],
          [2.0, 5.0, -1.0, 2.0],
          [-1.5, 2.7, 3.3, -0.8]]

weights = [[0.2, 0.8, -0.5, 1.0],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]

biases = [2.0, 3.0, 0.5]

layer_outputs = np.dot(inputs, np.array(weights).T) + biases

print(layer_outputs)
# Out:
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]

# %%
# Add another layer

# %% [markdown]
# # Artificial Neural Networks - Forward Propagation
#
# ## Introduction
#
# In this lab, we will build a neural network from scratch and code how it performs predictions using forward propagation. Please note that all deep learning libraries have the entire training and prediction processes implemented, and so in practice you wouldn't really need to build a neural network from scratch. However, hopefully completing this lab will help you understand neural networks and how they work even better.
#
# ## Artificial Neural Networks (ANN) - Forward Propagation
# Here is a neural network that takes two inputs, has one hidden layer with two nodes, and an output layer with one node.

# %% [markdown]
# <img src="http://cocl.us/neural_network_example" alt="Neural Network Example" width="600px">

# %% [markdown]
# Let's start by randomly initializing the weights and the biases in the network. We have 6 weights and 3 biases, one for each node in the hidden layer as well as for each node in the output layer.

# %%
import numpy as np

# %% [markdown]
# NumPy is a powerful open-source library in Python that provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. It is widely used for scientific computing and data analysis.

# %%
weights = np.around(np.random.uniform(size=6), decimals=2) # initialize weights randomly
biases = np.around(np.random.uniform(size=3), decimals=2) # initialize the biases randomly

print(weights)
print(biases)
# Out:
# [0.23 0.93 0.98 0.66 0.36 0.62]
# [0.68 0.49 0.55]

# %%
x_1 = .5 #input 1
x_2 = .85 # input 2

print('x1 is {} and x2 is {}' .format(x_1, x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %% [markdown]
# Let's start by computing the weighted sum of the inputs, $z_{1,1}$, at the first node of the hidden layer

# %%
z_11 = x_1 * weights[0] + x_2 * weights[1] + biases[0]

print('The weighted sum of teh inputs at the first node in the hidden layer is {}' .format(z_11))
# Out:
# The weighted sum of teh inputs at the first node in the hidden layer is 1.5855000000000001

# %% [markdown]
# Next, let's compute the weighted sum of the inputs, $z_{1,2}$, at the second mode of the hidden layer. Assign the value to **z_12**

# %%
### type your answer here

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- The correct answer is:
# z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]
# -->

# %%
print('The weighted sum of the inputs at the second node in the hidden layer is {}' .format(np.around(z_12,decimals=4)))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 1.541

# %% [markdown]
# Next, assuming a sigmoid activation function, let's compute the activation of the first node, $a_{1,1}$, in the hidden layer.

# %%
a_11 = 1.0/(1.0 + np.exp(-z_11))

print('The activation of the first node in the hidden layer is {}' .format(np.around(a_11, decimals=4)))
# Out:
# The activation of the first node in the hidden layer is 0.83

# %% [markdown]
# Let's also compute the activation of the second node, $a_{1,2}$, in the hidden layer. Assign the value to **a_12**.

# %%
### type your answer here

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- The correct answer is:
# a_12 = 1.0/(1.0 + np.exp(-z_12))
# -->

# %%
print('The activation of the second node in the hidden layer is {}' .format(np.around(a_12, decimals=4)))
# Out:
# The activation of the second node in the hidden layer is 0.8236

# %% [markdown]
# Now these activations will serve as teh inputs to the output layer. So, let's compute the weighted sum of these inputs to the node in the ouptuput layer.
# Assign the value to **z_2**

# %%
### type your answer here

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- The correct answer is:
# z_2 = a_11 * weights[4] + a_12 * weights[5] + biases[2]
# -->

# %%
print('The weighted sum of the inputs at the node in the output layer is {}' .format(np.around(z_2, decimals=4)))
# Out:
# The weighted sum of the inputs at the node in the output layer is 1.3594

# %% [markdown]
# Finally, let's compute the output of the network as the activation of the node in the output layer. Assign the value to **a_2**.

# %%
### type your answer here

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- The correct answer is:
# a_2 = 1.0/(1.0 + np.exp(-z_2))
# -->

# %%
print('The output of the network for x1 = .5 and x2 = .85 is {}' .format(np.around(a_2, decimals=4)))
# Out:
# The output of the network for x1 = .5 and x2 = .85 is 0.7957

# %% [markdown]
# <hr>

# %%
# Code to generate the plot: 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a grid of input values
x1 = np.linspace(-3, 3, 100)
x2 = np.linspace(-3, 3, 100)
X1, X2 = np.meshgrid(x1, x2)

# Define the weight vector
w = np.array([1, 1])

# Compute the output y based on a simple linear model
Y = np.sign(w[0] * X1 + w[1] * X2)

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface with y values only at -1, 0, and 1
ax.plot_surface(X1, X2, Y, cmap='coolwarm', alpha=0.8, rstride=1, cstride=1, edgecolor='none')

# Highlight the decision boundary where y=0
ax.contour(X1, X2, Y, levels=[0], colors='black', linestyles='dashed')

# Plot the weight vector
ax.quiver(0, 0, 0, w[0], w[1], 0, color='red', linewidth=2, arrow_length_ratio=0.2, label='Weight Vector')

# Superimpose "W" label at the end of the weight vector
ax.text(w[0], w[1], 0, 'W', color='red', fontsize=12, weight='bold')

# Labeling the axes
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
ax.set_title('Enhanced 3D Plot with Weight Vector and Discrete y Values')

# Set y limits to -1, 0, 1
ax.set_zticks([-1, 0, 1])

# Save the plot as a jpg file
plt.savefig('C:\\Users\\Dr. Hojin Moon\\OneDrive - CSULB\\Teaching\\STAT 479\\3D_plot_with_weight_vector.jpg', format='jpg')

plt.show()
